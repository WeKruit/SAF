# %% [markdown]
# # 10_combination_explorer
#
# 只查看 registry 与人工审核允许的一维/二维组合；不在 Notebook 创建新 predicate 或搜索三阶组合。

# %%
from prediction_market.sports.nfl_factor_lab import run_factor_discovery, verify_and_load_x13_inputs

claim_boundary = "PRELIMINARY_SOURCE_TIME_ONLY"
verified_inputs = verify_and_load_x13_inputs()
feature_view = None
registered_discovery = None
if feature_view is not None:
    registered_discovery = run_factor_discovery(verified_inputs, feature_view)

# %%
display({"claim_boundary": claim_boundary, "registered_combinations": registered_discovery})
