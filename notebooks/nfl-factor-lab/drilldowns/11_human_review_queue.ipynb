# %% [markdown]
# # 11_human_review_queue
#
# 逐项显示定义、具体 case、coverage、异常和 Dashboard 定位，供 ACCEPT / REDEFINE / DATA_GAP / REJECT。

# %%
from prediction_market.sports.nfl_factor_lab import run_factor_discovery, verify_and_load_x13_inputs

claim_boundary = "PRELIMINARY_SOURCE_TIME_ONLY"
verified_inputs = verify_and_load_x13_inputs()
feature_view = None
review_queue = None
if feature_view is not None:
    review_queue = run_factor_discovery(verified_inputs, feature_view)

# %%
allowed_review_status = ("ACCEPT", "REDEFINE", "DATA_GAP", "REJECT")
display({"claim_boundary": claim_boundary, "allowed_review_status": allowed_review_status, "review_queue": review_queue})
