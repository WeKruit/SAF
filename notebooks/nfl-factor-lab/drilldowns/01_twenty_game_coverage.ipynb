# %% [markdown]
# # 01_twenty_game_coverage
#
# 查看冻结 20 场的 game、episode、market、venue、路径和缺失覆盖，不改变选场。

# %%
from prediction_market.sports.nfl_factor_lab import verify_and_load_x13_inputs

claim_boundary = "PRELIMINARY_SOURCE_TIME_ONLY"
verified_inputs = verify_and_load_x13_inputs()

# %%
display({"claim_boundary": claim_boundary, "coverage": verified_inputs})
