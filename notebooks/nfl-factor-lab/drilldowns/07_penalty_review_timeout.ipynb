# %% [markdown]
# # 07_penalty_review_timeout
#
# 检查 penalty disposition、no-play、review/reversal 与 timeout state。

# %%
from prediction_market.sports.nfl_factor_lab import build_sports_feature_view, verify_and_load_x13_inputs

claim_boundary = "PRELIMINARY_SOURCE_TIME_ONLY"
verified_inputs = verify_and_load_x13_inputs()
verified_row_inputs = None
sports_feature_view = None
if verified_row_inputs is not None:
    sports_feature_view = build_sports_feature_view(verified_inputs, **verified_row_inputs)

# %%
display({"claim_boundary": claim_boundary, "administrative_features": sports_feature_view})
